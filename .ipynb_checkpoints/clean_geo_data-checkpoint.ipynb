# %%
# !pip3 install geopandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geopandas in /Users/AndrewBlumenthal/Library/Python/3.9/lib/python/site-packages (0.14.0)
# Requirement already satisfied: pandas>=1.4.0 in /Users/AndrewBlumenthal/Library/Python/3.9/lib/python/site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: packaging in /Users/AndrewBlumenthal/Library/Python/3.9/lib/python/site-packages (from geopandas) (23.2)
# Requirement already satisfied: fiona>=1.8.21 in /Users/AndrewBlumenthal/Library/Python/3.9/lib/python/site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: shapely>=1.8.0 in /Users/AndrewBlumenthal/Library/Python/3.9/lib/python/site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: pyproj>=3.3.0 in /Users/AndrewBlumenthal/Library/Python/3.9/lib/python/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: click~=8.0 in /Users/AndrewBlumenthal/Library/Python/3.9/lib/python/site-packages (from fiona>=1.8.21->geopandas) (8.1.7)
# Requirement already satisfied: importlib-metadata in /Users/AndrewBlumenthal/Library/Python/3.9/lib/python/site-packages (from fiona>=1.8.21->geopandas) (6.8.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/AndrewBlumenthal/Library/Python/3.9/lib/python/site-packages (from fiona>=1.8.21->geopandas) (23.1.0)
# Requirement already satisfied: cligj>=0.5 in /Users/AndrewBlumenthal/Library/Python/3.9/lib/python/site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: setuptools in /Users/AndrewBlumenthal/Library/Python/3.9/lib/python/site-packages (from fiona>=1.8.21->geopandas) (68.2.2)
# Requirement already satisfied: click-plugins>=1.0 in /Users/AndrewBlumenthal/Library/Python/3.9/lib/python/site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: six in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from fiona>=1.8.21->geopandas) (1.15.0)
# Requirement already satisfied: certifi in /Users/AndrewBlumenthal/Library/Python/3.9/lib/python/site-packages (from fiona>=1.8.21->geopandas) (2023.7.22)
# Requirement already satisfied: tzdata>=2022.1 in /Users/AndrewBlumenthal/Library/Python/3.9/lib/python/site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/AndrewBlumenthal/Library/Python/3.9/lib/python/site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/AndrewBlumenthal/Library/Python/3.9/lib/python/site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/AndrewBlumenthal/Library/Python/3.9/lib/python/site-packages (from pandas>=1.4.0->geopandas) (1.26.1)
# Requirement already satisfied: zipp>=0.5 in /Users/AndrewBlumenthal/Library/Python/3.9/lib/python/site-packages (from importlib-metadata->fiona>=1.8.21->geopandas) (3.17.0)
# WARNING: You are using pip version 21.2.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import geopandas as gpd
from shapely.geometry import mapping
import numpy as np

# %%
print("hello")
# Out:
# hello

# %%
geo_data = gpd.read_file("./data/ne_50m_admin_0_countries.shp")

# %%
type(geo_data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
geo_data.head(3)

columns = [
    "ADMIN",
    "CONTINENT",
    "geometry"
]

geo_data[columns].head(3)
# Out:
#       ADMIN CONTINENT                                           geometry
# 0  Zimbabwe    Africa  POLYGON ((31.28789 -22.40205, 31.19727 -22.344...
# 1    Zambia    Africa  POLYGON ((30.39609 -15.64307, 30.25068 -15.643...
# 2     Yemen      Asia  MULTIPOLYGON (((53.08564 16.64839, 52.58145 16...

# %%
geo_data[geo_data.CONTINENT == "North America"].ADMIN.unique()
# Out:
# array(['United States Virgin Islands', 'Puerto Rico',
#        'United States of America', 'Anguilla', 'Cayman Islands',
#        'Bermuda', 'British Virgin Islands', 'Turks and Caicos Islands',
#        'Montserrat', 'Trinidad and Tobago',
#        'Saint Vincent and the Grenadines', 'Saint Lucia',
#        'Saint Kitts and Nevis', 'Panama', 'Nicaragua', 'Aruba', 'Curaçao',
#        'Mexico', 'Jamaica', 'Honduras', 'Haiti', 'Guatemala', 'Grenada',
#        'Saint Pierre and Miquelon', 'Saint Martin', 'Saint Barthelemy',
#        'El Salvador', 'Dominican Republic', 'Dominica', 'Greenland',
#        'Cuba', 'Costa Rica', 'Canada', 'Belize', 'Barbados',
#        'The Bahamas', 'Antigua and Barbuda', 'Sint Maarten'], dtype=object)

# %%
for idx, row in geo_data[(geo_data.CONTINENT == "North America")].iterrows():
    print(row)
# Out:
# featurecla                                      Admin-0 country
# scalerank                                                     3
# LABELRANK                                                     6
# SOVEREIGNT                             United States of America
# SOV_A3                                                      US1
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-64.84501953124999 18.33007812...
# Name: 12, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     5
# SOVEREIGNT                             United States of America
# SOV_A3                                                      US1
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-66.12939453125 18.44492187499...
# Name: 15, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     5
# LABELRANK                                                     2
# SOVEREIGNT                             United States of America
# SOV_A3                                                      US1
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-132.746875 56.525683593749996...
# Name: 16, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     6
# SOVEREIGNT                                       United Kingdom
# SOV_A3                                                      GB1
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      POLYGON ((-63.001220703125 18.22177734374999, ...
# Name: 21, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     5
# SOVEREIGNT                                       United Kingdom
# SOV_A3                                                      GB1
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-81.36953125 19.348876953125, ...
# Name: 23, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     3
# LABELRANK                                                     6
# SOVEREIGNT                                       United Kingdom
# SOV_A3                                                      GB1
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      POLYGON ((-64.73027343749999 32.29345703125, -...
# Name: 24, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     3
# LABELRANK                                                     6
# SOVEREIGNT                                       United Kingdom
# SOV_A3                                                      GB1
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-64.39521484375 18.46459960937...
# Name: 25, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     3
# LABELRANK                                                     6
# SOVEREIGNT                                       United Kingdom
# SOV_A3                                                      GB1
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-71.66142578124999 21.76523437...
# Name: 26, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     3
# LABELRANK                                                     6
# SOVEREIGNT                                       United Kingdom
# SOV_A3                                                      GB1
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      POLYGON ((-62.1484375 16.74033203124999, -62.1...
# Name: 27, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     3
# LABELRANK                                                     5
# SOVEREIGNT                                  Trinidad and Tobago
# SOV_A3                                                      TTO
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-60.756298828125 11.1785156249...
# Name: 38, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     6
# SOVEREIGNT                     Saint Vincent and the Grenadines
# SOV_A3                                                      VCT
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-61.17451171875 13.15810546874...
# Name: 71, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     6
# SOVEREIGNT                                          Saint Lucia
# SOV_A3                                                      LCA
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      POLYGON ((-60.89521484375 13.821972656249997, ...
# Name: 72, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     3
# LABELRANK                                                     6
# SOVEREIGNT                                Saint Kitts and Nevis
# SOV_A3                                                      KNA
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-62.5322265625 17.121875000000...
# Name: 73, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     4
# SOVEREIGNT                                               Panama
# SOV_A3                                                      PAN
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-77.37421875 8.658300781249991...
# Name: 84, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     5
# SOVEREIGNT                                            Nicaragua
# SOV_A3                                                      NIC
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      POLYGON ((-83.15751953124999 14.99306640624999...
# Name: 92, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     3
# LABELRANK                                                     5
# SOVEREIGNT                                          Netherlands
# SOV_A3                                                      NL1
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      POLYGON ((-69.89912109375 12.452001953124991, ...
# Name: 97, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     3
# LABELRANK                                                     5
# SOVEREIGNT                                          Netherlands
# SOV_A3                                                      NL1
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      POLYGON ((-68.75107421874999 12.05976562499999...
# Name: 98, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     2
# SOVEREIGNT                                               Mexico
# SOV_A3                                                      MEX
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-117.128271484375 32.533349609...
# Name: 109, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     4
# SOVEREIGNT                                              Jamaica
# SOV_A3                                                      JAM
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      POLYGON ((-77.261474609375 18.457421874999994,...
# Name: 136, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     5
# SOVEREIGNT                                             Honduras
# SOV_A3                                                      HND
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-83.15751953124999 14.99306640...
# Name: 147, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     5
# SOVEREIGNT                                                Haiti
# SOV_A3                                                      HTI
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-71.779248046875 19.7181640624...
# Name: 148, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     3
# SOVEREIGNT                                            Guatemala
# SOV_A3                                                      GTM
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      POLYGON ((-92.23515624999999 14.54541015625, -...
# Name: 152, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     6
# SOVEREIGNT                                              Grenada
# SOV_A3                                                      GRD
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      POLYGON ((-61.71552734375 12.012646484374997, ...
# Name: 153, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     4
# LABELRANK                                                     4
# SOVEREIGNT                                               France
# SOV_A3                                                      FR1
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-56.15073242187499 46.76240234...
# Name: 161, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     3
# LABELRANK                                                     6
# SOVEREIGNT                                               France
# SOV_A3                                                      FR1
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      POLYGON ((-63.011181640625 18.06894531249999, ...
# Name: 163, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     3
# LABELRANK                                                     6
# SOVEREIGNT                                               France
# SOV_A3                                                      FR1
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      POLYGON ((-62.831933593749994 17.87646484375, ...
# Name: 164, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     6
# SOVEREIGNT                                          El Salvador
# SOV_A3                                                      SLV
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      POLYGON ((-89.36259765624999 14.416015625, -89...
# Name: 175, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     5
# SOVEREIGNT                                   Dominican Republic
# SOV_A3                                                      DOM
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      POLYGON ((-71.768310546875 18.03916015624999, ...
# Name: 178, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     6
# SOVEREIGNT                                             Dominica
# SOV_A3                                                      DMA
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      POLYGON ((-61.281689453125 15.2490234375, -61....
# Name: 179, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     3
# SOVEREIGNT                                              Denmark
# SOV_A3                                                      DN1
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-29.952880859375 83.56484375, ...
# Name: 181, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     3
# SOVEREIGNT                                                 Cuba
# SOV_A3                                                      CU1
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-81.83745117187499 23.16303710...
# Name: 187, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     5
# SOVEREIGNT                                           Costa Rica
# SOV_A3                                                      CRI
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      POLYGON ((-82.56357421874999 9.57666015625, -8...
# Name: 190, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     2
# SOVEREIGNT                                               Canada
# SOV_A3                                                      CAN
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-132.655517578125 54.127490234...
# Name: 202, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     6
# SOVEREIGNT                                               Belize
# SOV_A3                                                      BLZ
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-89.16147460937499 17.81484374...
# Name: 216, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     5
# SOVEREIGNT                                             Barbados
# SOV_A3                                                      BRB
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      POLYGON ((-59.493310546874994 13.0819824218749...
# Name: 219, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     4
# SOVEREIGNT                                          The Bahamas
# SOV_A3                                                      BHS
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-77.65771484375 24.24946289062...
# Name: 222, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     6
# SOVEREIGNT                                  Antigua and Barbuda
# SOV_A3                                                      ATG
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((-61.716064453125 17.0370117187...
# Name: 232, Length: 169, dtype: object
# featurecla                                      Admin-0 country
# scalerank                                                     3
# LABELRANK                                                     6
# SOVEREIGNT                                          Netherlands
# SOV_A3                                                      NL1
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      POLYGON ((-63.123046875 18.06894531249999, -63...
# Name: 240, Length: 169, dtype: object

# %%
# remove_list = [
#     'Vatican',
#     'Jersey', 'Guernsey', 'Isle of Man',
#     'San Marino',
#     'Russia',
#     'Monaco',
#     'Liechtenstein',
#     'Aland',
#     'Faroe Islands',
#     'Andorra'
# ]

country_coords = {}
for idx, row in geo_data[(geo_data.CONTINENT == "North America")].iterrows():
    geojson_obj = mapping(row["geometry"])
    geo_coords = geojson_obj["coordinates"]
    idx = np.argmax([len(coords[0]) for coords in geo_coords])
    country_coords[row["ADMIN"]] = geo_coords[idx]

# %%
countries = {}
for country_name, country_coord in country_coords.items():
    while len(country_coord) < 5:
        country_coord = country_coord[0]
    countries[country_name] = country_coord

# %%
import json

with open('data/country_coords.json', 'w') as f:
    json.dump(countries, f)
